# %%
import pandas as pd

# %%
artist = "nin.csv"

artist = pd.read_csv(artist, usecols = ['album',
                                        'name',
                                        'duration_ms',
                                        'key',
                                        'mode',
                                        'time_signature',
                                        'acousticness',
                                        'danceability',
                                        'energy',
                                        'instrumentalness',
                                        'liveness',
                                        'loudness',
                                        'speechiness',
                                        'tempo',
                                        'valence'])

artist_df = pd.DataFrame(artist)

artist_df.head()
# Out:
#                 album                         name  duration_ms  key  mode  \
# 0  Ghosts V: Together  Letting Go While Holding On       578943    4     1
# 1  Ghosts V: Together                     Together       603649    0     0
# 2  Ghosts V: Together              Out In The Open       315053    9     1
# 3  Ghosts V: Together                   With Faith       580363    8     1
# 4  Ghosts V: Together                        Apart       815434   10     1
#
#    time_signature  acousticness  danceability  energy  instrumentalness  \
# 0               4         0.979         0.116   0.130             0.974
# 1               4         0.928         0.174   0.165             0.931
# 2               4         0.944         0.127   0.408             0.901
# 3               4         0.971         0.473   0.277             0.957
# 4               4         0.877         0.117   0.228             0.912
#
#    liveness  loudness  speechiness    tempo  valence
# 0    0.1100   -20.029       0.0370   79.852   0.0386
# 1    0.0944   -20.291       0.0440  119.986   0.0399
# 2    0.0898   -13.423       0.0404   60.076   0.0349
# 3    0.1170   -17.038       0.0340  119.985   0.0400
# 4    0.0859   -18.281       0.0379   90.977   0.0291

# %%
artist_df['mode'] = artist_df['mode'].map({0: "Minor", 
                                           1: "Major"
                                          })

# %%
artist_df['key'] = artist_df['key'].map({0: "C (also B♯, Ddouble flat)", 
                                         1: "C♯, D♭ (also Bdouble sharp)", 
                                         2: "D (also Cdouble sharp, Edouble flat)", 
                                         3: "D♯, E♭ (also Fdouble flat)", 
                                         4: "E (also Ddouble sharp, F♭)", 
                                         5: "F (also E♯, Gdouble flat)", 
                                         6: "F♯, G♭ (also Edouble sharp)", 
                                         7: "G (also Fdouble sharp, Adouble flat)", 
                                         8: "G♯, A♭", 
                                         9: "A (also Gdouble sharp, Bdouble flat)", 
                                         10: "A♯, B♭ (also Cdouble flat)", 
                                         11: "B (also Adouble sharp, C♭)"
                                        })

# %% [markdown]
# # Spotify Features
#
# **acousticness** - A confidence measure from 0.0 to 1.0 of whether the track is acoustic. 1.0 represents high confidence the track is acoustic.
#
# **danceability** - Danceability describes how suitable a track is for dancing based on a combination of musical elements including tempo, rhythm stability, beat strength, and overall regularity. A value of 0.0 is least danceable and 1.0 is most danceable.
#
# **energy** - Energy is a measure from 0.0 to 1.0 and represents a perceptual measure of intensity and activity. Typically, energetic tracks feel fast, loud, and noisy. For example, death metal has high energy, while a Bach prelude scores low on the scale. Perceptual features contributing to this attribute include dynamic range, perceived loudness, timbre, onset rate, and general entropy.
#
# **instrumentalness** - Predicts whether a track contains no vocals. “Ooh” and “aah” sounds are treated as instrumental in this context. Rap or spoken word tracks are clearly “vocal”. The closer the instrumentalness value is to 1.0, the greater likelihood the track contains no vocal content. Values above 0.5 are intended to represent instrumental tracks, but confidence is higher as the value approaches 1.0.
#
# **liveness** - Detects the presence of an audience in the recording. Higher liveness values represent an increased probability that the track was performed live. A value above 0.8 provides strong likelihood that the track is live.
#
# **loudness** - The overall loudness of a track in decibels (dB). Loudness values are averaged across the entire track and are useful for comparing relative loudness of tracks. Loudness is the quality of a sound that is the primary psychological correlate of physical strength (amplitude). Values typical range between -60 and 0 db.
#
# **speechiness** - Speechiness detects the presence of spoken words in a track. The more exclusively speech-like the recording (e.g. talk show, audio book, poetry), the closer to 1.0 the attribute value. Values above 0.66 describe tracks that are probably made entirely of spoken words. Values between 0.33 and 0.66 describe tracks that may contain both music and speech, either in sections or layered, including such cases as rap music. Values below 0.33 most likely represent music and other non-speech-like tracks.
#
# **valence** - A measure from 0.0 to 1.0 describing the musical positiveness conveyed by a track. Tracks with high valence sound more positive (e.g. happy, cheerful, euphoric), while tracks with low valence sound more negative (e.g. sad, depressed, angry).
#
# **tempo** - The overall estimated tempo of a track in beats per minute (BPM). In musical terminology, tempo is the speed or pace of a given piece and derives directly from the average beat duration.

# %%
artist_df = artist_df.set_index(['album'])

album_df = artist_df.loc['Ghosts VI: Locusts']

album_df
# Out:
#                                                name  duration_ms  \
# album
# Ghosts VI: Locusts                 The Cursed Clock       420797
# Ghosts VI: Locusts              Around Every Corner       652650
# Ghosts VI: Locusts              The Worriment Waltz       565679
# Ghosts VI: Locusts                    Run Like Hell       337678
# Ghosts VI: Locusts  When It Happens (Don't Mind Me)       175729
# Ghosts VI: Locusts              Another Crashed Car       143510
# Ghosts VI: Locusts                         Temp Fix       106935
# Ghosts VI: Locusts                      Trust Fades       192779
# Ghosts VI: Locusts               A Really Bad Night       293100
# Ghosts VI: Locusts                  Your New Normal       225034
# Ghosts VI: Locusts                     Just Breathe       420448
# Ghosts VI: Locusts                 Right Behind You       102716
# Ghosts VI: Locusts             Turn This Off Please       788454
# Ghosts VI: Locusts                         So Tired       224569
# Ghosts VI: Locusts                      Almost Dawn       334172
#
#                                                      key   mode  \
# album
# Ghosts VI: Locusts  G (also Fdouble sharp, Adouble flat)  Major
# Ghosts VI: Locusts  D (also Cdouble sharp, Edouble flat)  Major
# Ghosts VI: Locusts             C (also B♯, Ddouble flat)  Minor
# Ghosts VI: Locusts  A (also Gdouble sharp, Bdouble flat)  Major
# Ghosts VI: Locusts            D♯, E♭ (also Fdouble flat)  Major
# Ghosts VI: Locusts  D (also Cdouble sharp, Edouble flat)  Major
# Ghosts VI: Locusts           F♯, G♭ (also Edouble sharp)  Major
# Ghosts VI: Locusts             C (also B♯, Ddouble flat)  Major
# Ghosts VI: Locusts  D (also Cdouble sharp, Edouble flat)  Minor
# Ghosts VI: Locusts            B (also Adouble sharp, C♭)  Minor
# Ghosts VI: Locusts             F (also E♯, Gdouble flat)  Minor
# Ghosts VI: Locusts  A (also Gdouble sharp, Bdouble flat)  Minor
# Ghosts VI: Locusts  A (also Gdouble sharp, Bdouble flat)  Major
# Ghosts VI: Locusts           F♯, G♭ (also Edouble sharp)  Major
# Ghosts VI: Locusts  D (also Cdouble sharp, Edouble flat)  Minor
#
#                     time_signature  acousticness  danceability   energy  \
# album
# Ghosts VI: Locusts               4        0.9470         0.395  0.15700
# Ghosts VI: Locusts               3        0.9320         0.346  0.41500
# Ghosts VI: Locusts               3        0.9740         0.110  0.21900
# Ghosts VI: Locusts               4        0.8910         0.559  0.57000
# Ghosts VI: Locusts               4        0.0979         0.434  0.75900
# Ghosts VI: Locusts               3        0.8220         0.524  0.20800
# Ghosts VI: Locusts               4        0.9030         0.524  0.29200
# Ghosts VI: Locusts               4        0.9720         0.478  0.13300
# Ghosts VI: Locusts               4        0.9600         0.115  0.13500
# Ghosts VI: Locusts               4        0.6240         0.698  0.25900
# Ghosts VI: Locusts               3        0.7770         0.168  0.42700
# Ghosts VI: Locusts               5        0.8780         0.245  0.00564
# Ghosts VI: Locusts               4        0.7630         0.376  0.54100
# Ghosts VI: Locusts               3        0.8660         0.235  0.03660
# Ghosts VI: Locusts               4        0.8990         0.342  0.38200
#
#                     instrumentalness  liveness  loudness  speechiness  \
# album
# Ghosts VI: Locusts          0.961000    0.1660   -16.565       0.0389
# Ghosts VI: Locusts          0.899000    0.0880   -11.900       0.0292
# Ghosts VI: Locusts          0.902000    0.1290   -21.715       0.0380
# Ghosts VI: Locusts          0.899000    0.2800   -11.501       0.0310
# Ghosts VI: Locusts          0.000227    0.1450    -6.879       0.0305
# Ghosts VI: Locusts          0.326000    0.1140   -26.220       0.1180
# Ghosts VI: Locusts          0.951000    0.1130   -16.523       0.0314
# Ghosts VI: Locusts          0.897000    0.1090   -22.249       0.0351
# Ghosts VI: Locusts          0.917000    0.1830   -21.338       0.0391
# Ghosts VI: Locusts          0.941000    0.1410   -15.863       0.0443
# Ghosts VI: Locusts          0.883000    0.2590   -15.712       0.0623
# Ghosts VI: Locusts          0.779000    0.1010   -29.713       0.0368
# Ghosts VI: Locusts          0.950000    0.1120   -15.298       0.0711
# Ghosts VI: Locusts          0.823000    0.1120   -26.729       0.0367
# Ghosts VI: Locusts          0.951000    0.0921   -18.732       0.0425
#
#                       tempo  valence
# album
# Ghosts VI: Locusts   64.996   0.0334
# Ghosts VI: Locusts   77.639   0.0595
# Ghosts VI: Locusts   59.445   0.0365
# Ghosts VI: Locusts  146.020   0.0826
# Ghosts VI: Locusts  140.020   0.0375
# Ghosts VI: Locusts  137.537   0.1210
# Ghosts VI: Locusts  136.098   0.1570
# Ghosts VI: Locusts  127.972   0.1860
# Ghosts VI: Locusts   80.735   0.0388
# Ghosts VI: Locusts  129.982   0.3320
# Ghosts VI: Locusts   88.906   0.0886
# Ghosts VI: Locusts  136.726   0.0372
# Ghosts VI: Locusts  146.036   0.0721
# Ghosts VI: Locusts   67.813   0.0373
# Ghosts VI: Locusts   89.875   0.0922

# %%
album_df.to_csv("locusts.csv")
